# %%
### 참고사이트: https://coding-kindergarten.tistory.com/91

#step1.selenium 패키지와 time 모듈 import
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import numpy as np
import pandas as pd
from selenium.webdriver.chrome.options import Options
options = Options()

# chrome을 전체화면으로 넓히는 옵션입니다.
options.add_argument('--start-fullscreen')


#step2.검색할 키워드 입력 
query = input()

#step3.크롬드라이버로 url로 접속
url = 'https://class101.net/categories/'
driver = webdriver.Chrome('/Users/parkjuhyeon/chromedriver')  ##크롬드라이버가 설치된 위치
driver.get(url)
time.sleep(3)

#step4.검색창에 키워드 입력 후 엔터
search_box = driver.find_element_by_css_selector(".SearchInput__Input-go705p-2.bxkgtv")
search_box.send_keys(query)
search_box.send_keys(Keys.RETURN)
time.sleep(2)


## 스크롤하기 ##
#ActionChains모듈 가져오기
from selenium.webdriver import ActionChains

#ActionChains생성
action = ActionChains(driver)
# Out:
# 개발
# <ipython-input-58-8124efaec5ec>:21: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('/Users/parkjuhyeon/chromedriver')  ##크롬드라이버가 설치된 위치
# <ipython-input-58-8124efaec5ec>:26: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_box = driver.find_element_by_css_selector(".SearchInput__Input-go705p-2.bxkgtv")
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# <ipython-input-58-8124efaec5ec> in <module>
#      24
#      25 #step4.검색창에 키워드 입력 후 엔터
# ---> 26 search_box = driver.find_element_by_css_selector(".SearchInput__Input-go705p-2.bxkgtv")
#      27 search_box.send_keys(query)
#      28 search_box.send_keys(Keys.RETURN)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_css_selector(self, css_selector)
#     800             stacklevel=2,
#     801         )
# --> 802         return self.find_element(by=By.CSS_SELECTOR, value=css_selector)
#     803
#     804     def find_elements_by_css_selector(self, css_selector) -> WebElement:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#    1236             value = '[name="%s"]' % value
#    1237
# -> 1238         return self.execute(Command.FIND_ELEMENT, {
#    1239             'using': by,
#    1240             'value': value})['value']
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     416         response = self.command_executor.execute(driver_command, params)
#     417         if response:
# --> 418             self.error_handler.check_response(response)
#     419             response['value'] = self._unwrap_value(
#     420                 response.get('value', None))
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     241                 alert_text = value['alert'].get('text')
#     242             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243         raise exception_class(message, screen, stacktrace)
#     244
#     245     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# NoSuchWindowException: Message: no such window: window was already closed
#   (Session info: chrome=96.0.4664.93)
# Stacktrace:
# 0   chromedriver                        0x000000010fb68ff9 __gxx_personality_v0 + 584201
# 1   chromedriver                        0x000000010faf4403 __gxx_personality_v0 + 106003
# 2   chromedriver                        0x000000010f6b0e38 chromedriver + 171576
# 3   chromedriver                        0x000000010f6a0a95 chromedriver + 105109
# 4   chromedriver                        0x000000010f6a1f42 chromedriver + 110402
# 5   chromedriver                        0x000000010f69ac22 chromedriver + 80930
# 6   chromedriver                        0x000000010f6b22c3 chromedriver + 176835
# 7   chromedriver                        0x000000010f715c7c chromedriver + 584828
# 8   chromedriver                        0x000000010f703d63 chromedriver + 511331
# 9   chromedriver                        0x000000010f6d982e chromedriver + 337966
# 10  chromedriver                        0x000000010f6dab65 chromedriver + 342885
# 11  chromedriver                        0x000000010fb24f1b __gxx_personality_v0 + 305451
# 12  chromedriver                        0x000000010fb3be23 __gxx_personality_v0 + 399411
# 13  chromedriver                        0x000000010fb418df __gxx_personality_v0 + 422639
# 14  chromedriver                        0x000000010fb3d17a __gxx_personality_v0 + 404362
# 15  chromedriver                        0x000000010fb19541 __gxx_personality_v0 + 257873
# 16  chromedriver                        0x000000010fb58f28 __gxx_personality_v0 + 518456
# 17  chromedriver                        0x000000010fb590b1 __gxx_personality_v0 + 518849
# 18  chromedriver                        0x000000010fb70498 __gxx_personality_v0 + 614056
# 19  libsystem_pthread.dylib             0x00007fffacecd93b _pthread_body + 180
# 20  libsystem_pthread.dylib             0x00007fffacecd887 _pthread_body + 0
# 21  libsystem_pthread.dylib             0x00007fffacecd08d thread_start + 13

# %%
## 리스트 리셋할 때 사용

title_list=[] ## 강의명 리스트
intro=[]      ## 강의 소개글을 tag<p> 단위로 받아올 리스트
intro_list=[] ## 강의 소개글을 강의 단위로 저장할 리스트
keyword=[]    ## 강의별 검색 키워드 저장 리스트

# %%
for n in range(1,9):   ## 1페이지 상단 강의1~강의8 크롤링 
    x_path = '//*[@id="wrapper"]/div/div[3]/div/section/div/div[4]/div[3]/div[1]/ul/li[{0}]/div/a'.format(n)
             
    driver.find_element_by_xpath(x_path).click()
    time.sleep(5)
    
        
    intro_text = driver.find_elements_by_tag_name("p") ## 소개글 가져오기
    intro=[]
    
    for t in intro_text:
        text = t.text
        intro.append(text)
    intro_list.append(' '.join(intro)) ## 소개글 가져와서 리스트에 저장
    

    keyword.append(query) ## 키워드 리스트 업데이트
    driver.back() #뒤로가기
    time.sleep(5)
# Out:
# <ipython-input-48-5771b0d41c1a>:4: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(x_path).click()
# <ipython-input-48-5771b0d41c1a>:8: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   intro_text = driver.find_elements_by_tag_name("p") ## 소개글 가져오기

# %%
for n in range(1,33):   ## 1페이지 하단 강의1~강의32까지 크롤링 
    x_path = '//*[@id="wrapper"]/div/div[3]/div/section/div/div[4]/div[3]/div[4]/div/div/ul/li[{0}]/div/a'.format(n)
             
    driver.find_element_by_xpath(x_path).click()
    time.sleep(5)
    
        
    intro_text = driver.find_elements_by_tag_name("p") ## 소개글 가져오기
    intro=[]
    
    for t in intro_text:
        text = t.text
        intro.append(text)
    intro_list.append(' '.join(intro)) ## 소개글 가져와서 리스트에 저장
    

    keyword.append(query) ## 키워드 리스트 업데이트
    driver.back() #뒤로가기
    time.sleep(5)
# Out:
# <ipython-input-49-a3419f6b5a13>:4: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(x_path).click()
# <ipython-input-49-a3419f6b5a13>:8: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   intro_text = driver.find_elements_by_tag_name("p") ## 소개글 가져오기

# %%
titles = driver.find_elements_by_css_selector(".Card__Title-sc-1esp5o0-4.bVCpyh")

for i in titles:
    title = i.text
    title_list.append(title)
# Out:
# <ipython-input-50-55bc1a781b43>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   titles = driver.find_elements_by_css_selector(".Card__Title-sc-1esp5o0-4.bVCpyh")

# %%
title_list
# Out:
# ['[✔️수강생PICK] 10년 차 개발자의 [게임 개발/앱 개발/프로그래밍]을 위한 C/C++ 입문',
#  '[🎁연말특가] 프로그래밍 스킬업을 위한 C++와 Cocos2d-x를 활용한 캐주얼 게임 개발',
#  '[🎁연말특가] [웹 개발자 단과반 1교시] HTML, CSS, JS 프론트엔드 속성 실무!',
#  '[🎁연말특가] [웹 개발자 단과반 2교시] MySQL, Node.js 백엔드 속성 실무!',
#  '[웹 개발자 단과반 3교시] 초간단 AWS 웹사이트 배포 및 구글 애널리틱스 코드 심기',
#  '고연봉 개발자가 되는 비법, 주니어 개발자 취업 가이드',
#  '4차산업혁명 VR, AR 개발 실습하기 Part.3 오큘러스 퀘스트로 시작하는 VR 개발',
#  '[🎁연말특가] 개발자가 되고 싶은 당신을 위해, 개발자가 되는 로드맵 A to Z',
#  '4차산업혁명 VR, AR 콘텐츠 제작 실무 (중급) Part.7 ARCore 컨텐츠 개발',
#  '4차산업혁명 VR, AR 개발 실습하기 Part.1 유니티에 익숙해지자',
#  '4차산업혁명 VR, AR 콘텐츠 제작 실무 (중급) Part.6 Tango를 통한 개발이론',
#  '4차산업혁명 VR, AR 개발 실습하기 Part.2 코딩을 시작해보자',
#  '[🎁연말특가] [취업 연계] 커리어 코스 - 한큐 프로의 JAVA 웹 개발자 양성 과정',
#  '[✔️수강생PICK] 15년 차 웹 개발자가 제대로 알려주는 웹 코딩 입문!',
#  '[🎁연말특가] React 로 웹 개발의 기초부터 프로덕션까지 :: To-Do, 메모앱 만들기',
#  '[🎁연말특가] 평범한 직장인에서 자산가가 된, 아이언키의 ⟪재개발 투자⟫ 완전 정복★',
#  '[🎁연말특가] SNS 서비스 개발로 배우는 자바 웹 프로그래밍 입문!',
#  '개발 직군 취업의 첫 걸음! 한 번에 합격하는 자기소개서 작성법',
#  '[🎁연말특가] 네이버 개발자 뮤와 함께하는 내인생 첫번째 앱 만들기',
#  '<1차매진>[넘쳐나는 규제 속 마지막 황금알, 재개발 투자] 쉽게 배우고 안전하게 투자하기',
#  '고연봉 받는 IT 커리어 풀 로드맵 : 개발자, PO, PM, 데이터 과학자',
#  '[🎁연말특가] 세상에서 가장 빠르게 AI 개발자 되기 + 세상에서 가장 쉽게 딥러닝(AI)서비스 런칭하기',
#  '[🎁연말특가] 화이트햇 해킹, IT 취준생과 현직 개발자를 위한 웹 해킹 입문!',
#  '언택트 키즈 직업체험 클래스 - 게임개발자 편',
#  '[🎁연말특가] 구글 AI 인증 강사와 함께하는 AI 개발 입문 Full 패키지',
#  '개발 지식 없어도 OK, 내가 생각하는 앱 서비스 기획하기',
#  '[✔️수강생PICK] 현직 대기업 개발자 푸와 함께하는 진짜 백엔드 시스템 실무!',
#  '[🎁연말특가] 예비/현직 웹 프로그래머를 위한 워드프레스 플러그인 개발!',
#  '프론트엔드 개발시 꼭 해봐야하는 실무 예제 Part.4 쿠키 라이브러리',
#  '프론트엔드 개발시 꼭 해봐야하는 실무 예제 Part.3 테이블 및 쿠키 활용',
#  '프론트엔드 개발시 꼭 해봐야하는 실무 예제 Part.2 로컬 데이터',
#  '프론트엔드 개발시 꼭 해봐야하는 실무 예제 Part.1 아코디언',
#  '[개정판] 정보처리기사 필기 - 제2과목 소프트웨어개발',
#  '4차산업혁명 VR, AR 콘텐츠 제작 실무 (중급) Part.1 VR 디자인 및 설계',
#  '프론트엔드 개발시 꼭 해봐야하는 실무 예제 Part.5 가상요소 디자인 및 팝업창',
#  '[🎁연말특가] [비전공자도 OK] 용돈 벌어주는 나만의 앱 직접 만들어보기',
#  '4차산업혁명 VR, AR 콘텐츠 제작 실무 (중급) Part.4 제작 스킬',
#  '4차산업혁명 VR, AR 콘텐츠 제작 실무 (중급) Part.3 제작 스킬',
#  '[🎁연말특가] 비전공자를 위한 이해할 수 있는 IT지식',
#  '입문부터 실무까지 한 번에 정복! 빵형과 함께하는 실전 Java',
#  '[코딩 첫걸음] 누구나 쉽게 만드는 나만의 다이어리 앱',
#  '4차산업혁명 VR, AR 콘텐츠 제작 실무 (중급) Part.5 네트워크 프로그래밍',
#  '4차산업혁명 VR, AR 콘텐츠 제작 실무 (중급) Part.2 AR 만들어보기',
#  '[🎁연말특가] 바닐라 자바스크립트로 배우는 모던 프론트엔드 실전!',
#  '[🎁연말특가] 풀스택 웹 개발로 배우는 확진자 지도 서비스 만들기',
#  '자바스크립트+jQuery 기초부터 실무까지 제대로 배우기 (기초) Part.1',
#  '[🎁연말특가] 비전공자를 위한 나만의 안드로이드 앱 만들기',
#  '[스타터패키지] 풀스택 웹 개발자되기 프론트엔드-백엔드-배포까지 속성으로 배우기!',
#  '[2주 완성] 정보처리기사 최신개정판 필기+실기 종합 클래스',
#  '[🎁연말특가] 클론코딩, 리액트로 소셜 네트워크 서비스 만들기',
#  '[0원 클래스] 프로그래밍 입문자를 위한 CSS 기초',
#  '[0원 클래스] 프로그래밍 입문자를 위한 HTML 기초',
#  '[🎁연말특가] 세상에서 제일 쉬운 파이썬 101',
#  '[라이브] 성장에 한계를 느끼는 순간, 스스로 돌파구를 찾는 개발자가 되려면 by 이종립',
#  'Java 스프링부트 프레임워크 제대로 배우기 (기초) 1 - 기초',
#  '[🎁연말특가] C#으로 시작하는 프로그래밍 입문 & 프로그램 만들기',
#  'C언어 기초에서 활용까지 제대로 배우기 (초급) Part.1 개요와 개발환경 설정',
#  '실무 예제 모음ZIP, 프론트엔드 실무 원큐에 끝내기',
#  '[스타터패키지] 입문부터 수익화까지 비전공자를 위한 앱 개발 패키지',
#  '[🎁연말특가] IT 주니어를 위한 실전 UX 디자인 개론',
#  '[0원 클래스] 30분 요약 강좌 시즌1 : HTML, CSS, JS, Python',
#  '[🎁연말특가] [컬리지] 프로덕트 매니저 (PM)',
#  '코딩부터 배포까지! 입문자도 할 수 있는 나만의 메신저 웹사이트 만들기',
#  'PyTorch로 쉽게 배우는 딥러닝 입문 클래스',
#  '[🎁연말특가] 머니해킹 심화 - 한 달 만에 5가지 자동 수익 시스템 만들기, IT사업 마스터',
#  '[🎁연말특가] 프로그래밍의 기본! C언어와 자료구조, 동시에 입문하기',
#  '[개정판] 정보처리기사 필기 - 제5과목 정보시스템 구축 관리',
#  '[💣오늘의 특가] 언리얼 엔진 중급, 영화 퀄리티의 3D 메타버스를 창조해요.',
#  '[100제 풀이] 예제로 마스터하는 Python(파이썬) 종합 클래스',
#  "[🎁연말특가] 연봉과 만족감을 함께 올리는 방법, '강점'으로 설계하는 일잘러 커리어",
#  '[🎁연말특가] IT 프로덕트 매니저(PM)로 성공적인 커리어 쌓기',
#  '[🎁연말특가] 스콘 맛집으로 가는 가장 빠른 길, 10년의 노하우를 담은 "잘 팔리는 스콘"',
#  '[✔️수강생PICK] SQL 과 파이썬 데이터 분석 풀패키지, 비트코인, 부동산, 주식도 분석해보기!',
#  '[🏆TOP30] UIUX 디자인이 쉬워지는 디자인 시스템의 모든것',
#  '[💣오늘의 특가] [교재 / 신규도서 무료 증정] 커리어 코스 - 리베하얀 프로의 웹 퍼블리셔 양성 과정',
#  '[🎁연말특가] 20년 강사가 알려주면 초보자도 할 수 있다! 양식조리기능사 자격증',
#  '[💣오늘의 특가] AI 자동 투자 봇 만들기, 노트북으로 월급을 두 배 불리는 법',
#  '초보자를 위한 Native JavaScript UI 인터렉션 종합 클래스',
#  '[🎁연말특가] 서울대 출신 AI 연구직의 세상에서 제일 쉬운 머신러닝 101',
#  '[스타터패키지] 웹 프로그래밍 입문부터 리액트 활용 클론코딩까지',
#  '클라우드 컴퓨팅 Azure와 Azure DevOps로 데브옵스 시작하기 Part.2',
#  '[실전 100제] 예제로 마스터하는 Java (자바) Part.10 컬렉션, 패키지',
#  '[실전 100제] 예제로 마스터하는 Java (자바) Part.8 알고리즘',
#  '[실전 100제] 예제로 마스터하는 Java (자바) Part.7 OOP2',
#  '[실전 100제] 예제로 마스터하는 Java (자바) Part.6 OOP1',
#  '[실전 100제] 예제로 마스터하는 Java (자바) Part.5 함수',
#  '[실전 100제] 예제로 마스터하는 Java (자바) Part.4 배열',
#  '[실전 100제] 예제로 마스터하는 Java (자바) Part.3 조건문, 반복문',
#  '[실전 100제] 예제로 마스터하는 Java (자바) Part.2 자료형, 연산자',
#  '클라우드 컴퓨팅 Azure와 Azure DevOps로 데브옵스 시작하기 Part.1',
#  '[🎁연말특가] 취미부터 창업까지_ 전문가가 만든 것 같이 쉽고 안전하게 만드는 생화 케이크',
#  'JavaScript 플랫폼 Node.js 제대로 배우기 Part.3',
#  'JavaScript 플랫폼 Node.js 제대로 배우기 Part.2',
#  'JavaScript 플랫폼 Node.js 제대로 배우기 Part.1',
#  "[✔️수강생PICK] 저 아파트는 왜 비쌀까? 부동산 전문가들의 '아파트 실전 투자' 비법!",
#  '[100제 풀이] 예제로 마스터하는 Java(자바) 종합 클래스',
#  '[2020 개정] 정보처리기사 실기시험 제대로 따라잡기 Part.2',
#  '[🎁연말특가] 현직 게임 애니메이터에게 배우는 스파인 애니메이션 입문에서 마스터까지',
#  '[✔️수강생PICK] 손쉽게 건물주 되는 법, 소자본으로 부동산 디벨로퍼 시작하기',
#  '[✔️수강생PICK] Python 101: 매일 30분, 40일 동안! LV. 1 파이썬 기초 프로젝트',
#  '[🎁연말특가] 업계 9년간의 노하우를 담은, 블록체인 분석전문가 자격증 2급 과정(수료, 취득 가능)',
#  '[🎁연말특가] 마케터를 위한 데이터 사이언스 입문',
#  '공공데이터(오픈데이터) API 제대로 배우기 Part.4 API와 DB',
#  '공공데이터(오픈데이터) API 제대로 배우기 Part.1 JSON 데이터 처리',
#  '[🎁연말특가] 파이썬 첫걸음부터 풀패키지, 잔재미코딩의 자동화 프로그램 만들기!',
#  '자바스크립트+jQuery 기초부터 실무까지 제대로 배우기 (고급) Part.1',
#  '자바스크립트+jQuery 기초부터 실무까지 제대로 배우기 (중급) Part.6',
#  '자바스크립트+jQuery 기초부터 실무까지 제대로 배우기 (중급) Part.5',
#  '자바스크립트+jQuery 기초부터 실무까지 제대로 배우기 (중급) Part.4',
#  '자바스크립트+jQuery 기초부터 실무까지 제대로 배우기 (중급) Part.3',
#  '자바스크립트+jQuery 기초부터 실무까지 제대로 배우기 (중급) Part.2',
#  '자바스크립트+jQuery 기초부터 실무까지 제대로 배우기 (중급) Part.1',
#  '자바스크립트+jQuery 기초부터 실무까지 제대로 배우기 (기초) Part.8',
#  '자바스크립트+jQuery 기초부터 실무까지 제대로 배우기 (기초) Part.7',
#  '자바스크립트+jQuery 기초부터 실무까지 제대로 배우기 (기초) Part.6',
#  '자바스크립트+jQuery 기초부터 실무까지 제대로 배우기 (기초) Part.5',
#  '자바스크립트+jQuery 기초부터 실무까지 제대로 배우기 (기초) Part.4',
#  '자바스크립트+jQuery 기초부터 실무까지 제대로 배우기 (기초) Part.3',
#  '[실전 100제] 예제로 마스터하는 Java Part.9 자격증(COS Pro 2급)',
#  '[🎁연말특가] 북유럽 카페 메뉴를 집에서! - 눈과 입이 즐거운 스웨덴 케익&쿠키 현지인과 함께 만들어요',
#  '[🎁연말특가] 코알못을 위한 부업, 투자에 활용하는 실용주의 파이썬 코딩',
#  '[🏆TOP30] 러셀과 함께 언리얼 엔진으로 나만의 가상 세계 만들기',
#  '[✔️수강생PICK] 파이썬을 이용한 비트코인 자동매매 봇 만들기 풀 패키지',
#  '공공데이터(오픈데이터) API 제대로 배우기 Part.3 Python',
#  '공공데이터(오픈데이터) API 제대로 배우기 Part.2 JAVA, JSP',
#  "[🎁연말특가] 천공의 섬 메타버스 만들면서 '로블록스 코딩'해요!",
#  '[🎁연말특가] 지방대 출신에서 상위 1% 소득을 만든 100만 유튜버 김작가가 말하는 성공 가속도 법칙',
#  "[🎁연말특가] 취미부터 창업까지, 카페 음료는 '커픽처스'에게 쉽고 꼼꼼하게 배우세요.",
#  '[실전 100제] 예제로 마스터하는 Java (자바) Part.1 환경설정, 변수',
#  '예제로 공부하는 Python 100 문제풀이 Part.2 연산자, 조건문, 반복문',
#  '예제로 공부하는 Python 100 문제풀이 Part.1 변수, 자료형',
#  '유니티 엔진으로 배우는 3D 게임 이펙트 디자인 입문!',
#  '[🎁연말특가] 완벽한 기초부터 응용까지, 홈베이킹으로도 실패 없는 구움과자',
#  '분석, 예측모델, AWS 자동화까지! 연봉 높이는 데이터 과학자 포트폴리오 완성',
#  '[🎁연말특가] 셀프 네일부터 샵 테크닉까지 폴리젤의 모든 것',
#  '[🎁연말특가] 손으로 꼬물꼬물, 위빙으로 갖게 된 나만의 시간',
#  '[MINI] 68년 전통 삼진어묵 이금복 장인의 <집에서도 쉽게, 맞춤 수제 어묵 만들기>',
#  '[🎁연말특가] 요기요 머신러닝 엔지니어에게 배우는 추천시스템 입문',
#  '[🏆TOP30] 박신영의 기획하다-기획이 막막한 사람을 위한 기획입문',
#  '[🎁연말특가] 아름다운 라인을 잡아주는 연예인 경락 마사지',
#  '[🎁연말특가] 3D 메타버스를 창조하는 언리얼 엔진, 초급부터 중급까지 한 번에!',
#  '자바스크립트+jQuery 기초부터 실무까지 제대로 배우기 (기초) Part.2',
#  '[🎁연말특가] 글꼴의 맛 : 한글 디자인 마스터 (한글 레터링, 폰트 디자인)',
#  '자동매매 끝판왕 | 24시간 돌아가는 서버리스 트레이딩 시스템 만들기',
#  '오감을 자극하는 푸드아트! 자동차 샐러드 만들기 (4인분)',
#  '[🏆TOP30] 글씨의 진한 울림, 필림의 손글씨 교정 클래스',
#  '반짝반짝 별자리를 만나요! 우주 스토리와 함께하는 <키즈 별빛 탐험대>',
#  '[✔️수강생PICK] 행복한 부자들만 알던 마인드파워시크릿, 그들만의 부자되는 노하우대공개',
#  '[2주 완성] 완벽한 웹 퍼블리셔 포트폴리오 만들기',
#  '웹 퍼블리셔 포트폴리오 만들기 Part.3',
#  '웹 퍼블리셔 포트폴리오 만들기 Part.1',
#  '예제로 공부하는 Python 100 문제풀이 Part.5 OOP',
#  '예제로 공부하는 Python 100 문제풀이 Part.4 함수',
#  '예제로 공부하는 Python 100 문제풀이 Part.3 배열',
#  'Python(파이썬) 기초부터 실무까지 제대로 배우기 Part.19 파일과 예외처리',
#  'Python(파이썬) 기초부터 실무까지 제대로 배우기 Part.17 GUI 프로그래밍-2',
#  'Python(파이썬) 기초부터 실무까지 제대로 배우기 Part.11 자료구조',
#  '[🏆TOP30] 역대 최다 수강! 앵콜 기록! SNPE 2탄 고강도 인텐시브 클래스',
#  '[🔥트렌드특가] 화장품 소자본 창업하기! 창업 시간과 비용을 아껴드립니다.',
#  '[🎁연말특가] 홍석천의 실패를 줄이는 my 외식업 스토리',
#  '[✔️수강생PICK] 배부르게 날씬해지는 33일! - 자연식물식 다이어트',
#  "[🎁연말특가] 쉽게 구할 수 있는 재료로 근사하게! '솥밥' 하나로 맛있고 꽉 찬 식탁 만들기",
#  '[🎁연말특가] 그림책 작가 김유강에게 배우는 왕초보 동물 캐릭터 디자인',
#  '[🎁연말특가] 국내 유일 ADP 실기 클래스 Part 2! 통계분석과 머신러닝',
#  "[🔥트렌드특가] 보면서 따라하는 실전 경매! 천만 원으로 내집마련? '실전 경매 끝판왕' 복마마 클라쓰★",
#  '[🎁연말특가] All About Coffee! 4가지 도구로 경험하는 다채로운 커피의 세계',
#  "[🎁연말특가] 3D펜과 코딩으로 움직이는 미래도시 만들기! '펜톡 스마트 에코시티'",
#  '[🎁연말특가] 국내, 해외주식 놓쳤다면? 성장잠재력 NO.1 인도네시아의 삼★전자 주식 찾아보기!',
#  '[🎁연말특가] 청미당과 함께, 쉽고 건강하고 맛있는 쌀 베이킹',
#  '[❤️1+1할인] 주식투자, 제대로 공부하고 자동주식매매까지 한 번에 끝내기',
#  '[🎁연말특가] 게임음악 사운드디자이너가 되기위한 모든것 : CJ,SM 거쳐 탑 10 게임회사와 일하는 법',
#  'Java 스프링부트 프레임워크 제대로 배우기 (기초) 5 - 데이터베이스 연동 실습',
#  'Java 스프링부트 프레임워크 제대로 배우기 (기초) 4 - 데이터베이스 연동 이론',
#  'Java 스프링부트 프레임워크 제대로 배우기 (기초) 3 - DTO 객체 폼과 뷰페이지',
#  'Java 스프링부트 프레임워크 제대로 배우기 (기초) 2 - 컨트롤러와 맵핑처리',
#  'Python(파이썬) 기초부터 실무까지 제대로 배우기 Part.24 미니프로젝트',
#  'Python(파이썬) 기초부터 실무까지 제대로 배우기 Part.23',
#  'Python(파이썬) 기초부터 실무까지 제대로 배우기 Part.22 스레드',
#  'Python(파이썬) 기초부터 실무까지 제대로 배우기 Part.21',
#  'Python(파이썬) 기초부터 실무까지 제대로 배우기 Part.20',
#  'Python(파이썬) 기초부터 실무까지 제대로 배우기 Part.18 GUI 프로그래밍-3',
#  'Python(파이썬) 기초부터 실무까지 제대로 배우기 Part.16 GUI 프로그래밍-1',
#  'Python(파이썬) 기초부터 실무까지 제대로 배우기 Part.15 객체지향 프로그래밍-3',
#  'Python(파이썬) 기초부터 실무까지 제대로 배우기 Part.14 객체지향 프로그래밍-2',
#  'Python(파이썬) 기초부터 실무까지 제대로 배우기 Part.13 객체지향 프로그래밍-1',
#  'Python(파이썬) 기초부터 실무까지 제대로 배우기 Part.12 자료구조',
#  'Python(파이썬) 기초부터 실무까지 제대로 배우기 Part.10 자료구조',
#  'Python(파이썬) 기초부터 실무까지 제대로 배우기 Part.9 리스트-2',
#  'Python(파이썬) 기초부터 실무까지 제대로 배우기 Part.8 리스트-1',
#  'Python(파이썬) 기초부터 실무까지 제대로 배우기 Part.6 함수-1',
#  'Python(파이썬) 기초부터 실무까지 제대로 배우기 Part.5 반복문',
#  'Python(파이썬) 기초부터 실무까지 제대로 배우기 Part.4 조건문',
#  'Python(파이썬) 기초부터 실무까지 제대로 배우기 Part.3 자료형',
#  'Python(파이썬) 기초부터 실무까지 제대로 배우기 Part.2 변수와 계산',
#  'Python(파이썬) 기초부터 실무까지 제대로 배우기 Part.1 파이썬 소개',
#  '[🎁연말특가] 직접 피워낸 누룩으로 빚은 내 생애 첫 막걸리',
#  '[🎁연말특가] 바둑으로 일상을 특별하게! 표정이 살아있는 인공지능 앱으로 바둑을 배워보아요.',
#  '[🎁연말특가] 바나나가 악기가 된다? 신기한 코딩의 세계!',
#  '[🎁연말특가] 국내 유일 ADP 실기 클래스! 대한민국 상위 3%를 증명하는 법',
#  '구독자100명도 수익창출을? 강의만족도100%, 찐전문가의 <유튜브 수익화 20가지 비법>',
#  '[🎁연말특가] 누적 광고비 100억 돌파, 공식 대행사가 알려주는 GFA 전략',
#  '내 몸은 나의 것! 사회성 발달과 안전한 생활을 위한 경계 존중 교육',
#  "[🔥트렌드특가] 100억 자산가가 된 가난한 소년, 라라브레드 강호동의 '외식 창업의 모든 것'",
#  '[✔️수강생PICK] 멘탈이 바뀌면 인생도 바뀐다, 박세니의 실전 응용 심리학',
#  '[🎁연말특가] 나만의 의류 브랜드! 디자인부터 유통, 마케팅까지',
#  '[✔️수강생PICK] 원리를 알아야 실무가 보인다! 가장 쉽고 빠른 제품 3D 모델링(Rhino6)',
#  '[🎁연말특가] 영상 디자이너와 함께하는 쉽고 특별한 영상 디자인 클래스',
#  '[✔️수강생PICK] 1% 부와 행운의 최단거리, 더플러스 17가지 법칙!',
#  '[❤️1+1할인] 마인드파워 고수, 조성희의 부자 되는 노하우 2가지 클래스를 한 번에',
#  '[🎁연말특가] 마음을 위로하는 향긋한 티타임, 그린살롱과 함께하는 꽃차 생활',
#  '[🎁연말특가] 스마트팩토리, 파이썬으로 배우는 제조/공정 데이터 분석의 모든 것',
#  '닮은 연예인 찾기 서비스 제작 With 티처블머신',
#  '자바스크립트+jQuery 기초부터 실무까지 제대로 배우기 (고급) Part.6',
#  '예제로 공부하는 Python 100 문제풀이 Part.6 알고리즘, 문자열, 모듈, 자격증',
#  '코드 공식+반주 공식을 통해 모든 코드를 연주하고 작곡에 적용할 수 있게 됩니다!',
#  '[🔥트렌드특가] ⟪주식투자 어벤져스 : 이안⟫ • 트레이더 이안이 알려주는 기술적 분석의 모든 것',
#  '[🎁연말특가] [꿀조합 할인🍯] PD 추천 고퀄리티 수업! 뮤지컬부터 메이커 교육까지!',
#  'Python(파이썬) 기초부터 실무까지 제대로 배우기 Part.7 함수-2',
#  '파이썬으로 배우는 블록체인 - 비트코인, 암호화폐 제대로 배우기 Part.2',
#  '파이썬으로 배우는 블록체인 - 비트코인, 암호화폐 제대로 배우기 Part.1',
#  '[🎁연말특가] [꿀조합 할인🍯] 놀아도 놀아도 에너지가 넘치는 아이를 위해, 영어뮤지컬부터 골프까지!',
#  '[🎁연말특가] 박준우의 홈 파티 요리 클래스',
#  '영미권 No.1 과학교과서 ‘맥그로힐 사이언스’로 배우는 우주실험!',
#  '대한민국 영어 교사들의 선생님! JOY쌤의 엄마표 영어',
#  '[✔️수강생PICK] 코딩하는거니의 문과 감성 실용 파이썬, 나의 첫 프로그래밍!',
#  '[🎁연말특가] 내 최애 음료가 Tea 였다고? 건강하고 맛있게 즐기는 Tea 음료 만들기',
#  '한 번에 취득하는 빅데이터 분석기사 실기, 파이썬/판다스/머신러닝',
#  '[🎁연말특가] 머니해커의 자동으로 돈 버는 프로그램 입문부터 심화까지!',
#  '[🎁연말특가] 바디 밸런스&바른 자세 전문가 포그로스와 함께 하는 100일 솔루션',
#  '[✔️수강생PICK] 쉽고 맛있는 데일리 발효 소스와 활용요리',
#  '[🎁연말특가] 비전공자도 쉽게 배워 바로 써먹는 실무 활용 SQL',
#  'STEAM 융합놀이 포트폴리오로 초등 과학교과 정복하기!',
#  '[🎁연말특가] "로봇은 어떻게 움직여요?" 아이 질문에 페이퍼토이로 답해주기',
#  '[🎁연말특가] 초보도 금손 되는 한복 클래스! 체크무늬 여아 한복, 내 손으로 지어 입혀요',
#  '[🎁연말특가] 미국 주식 배당금으로 만드는 제 2의 월급, AI 자동 투자 봇으로 한방에 해결!',
#  '[🏆TOP30] 나만의 기술번역 노하우로 틈새번역시장 공략하기!',
#  '[🎁연말특가] 독서 습관의 골든타임, 인형극 책놀이로 사수하기!',
#  '[🎁연말특가] 오랫동안 시들지 않는 예쁜 꽃! 프레스플라워(압화)로 창업도 부업도 가능한 전문가 과정',
#  '[🏆TOP30] 극강의 리얼리즘 구현, Cinema 4D+Octane 3D 입문클래스',
#  '[🎁연말특가] 주식 자동화 코딩을 실전투자로 재밌게 배우기, 왕초보부터 고수까지']

# %%
print(len(title_list))
print(len(intro_list))
print(len(keyword))
# Out:
# 240
# 240
# 240

# %%
data = {"class_title" : title_list,
       "intro" : intro_list,
       "keyword" : keyword}

# %%
type(data)
# Out:
# dict

# %%
### DataFrame 행 넓이 최대 
pd.set_option('display.max_colwidth', -1)
# Out:
# <ipython-input-55-c3b6d9bbd837>:2: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
### DataFrame형태로 변환

df = pd.DataFrame.from_dict(data, orient='index')
df = df.transpose()
df
# Out:
#                                                   class_title  \
# 0    [✔️수강생PICK] 10년 차 개발자의 [게임 개발/앱 개발/프로그래밍]을 위한 C/C++ 입문
# 1    [🎁연말특가] 프로그래밍 스킬업을 위한 C++와 Cocos2d-x를 활용한 캐주얼 게임 개발
# 2    [🎁연말특가] [웹 개발자 단과반 1교시] HTML, CSS, JS 프론트엔드 속성 실무!
# 3    [🎁연말특가] [웹 개발자 단과반 2교시] MySQL, Node.js 백엔드 속성 실무!
# 4    [웹 개발자 단과반 3교시] 초간단 AWS 웹사이트 배포 및 구글 애널리틱스 코드 심기
# ..                                                ...
# 235  [🏆TOP30] 나만의 기술번역 노하우로 틈새번역시장 공략하기!
# 236  [🎁연말특가] 독서 습관의 골든타임, 인형극 책놀이로 사수하기!
# 237  [🎁연말특가] 오랫동안 시들지 않는 예쁜 꽃! 프레스플라워(압화)로 창업도 부업도 가능한 전문가 과정
# 238  [🏆TOP30] 극강의 리얼리즘 구현, Cinema 4D+Octane 3D 입문클래스
# 239  [🎁연말특가] 주식 자동화 코딩을 실전투자로 재밌게 배우기, 왕초보부터 고수까지
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 0                  이 클래스는 통해 C/C++ 언어를 토대로 기본적인 프로그래밍 에 대한 이해와 스킬업을 통해 어떤 언어로 코딩을 하느냐에 관계없이 프로그래밍을 가능하도록 여러분의 기초 실력을 단단하게 다질 수 있도록 만들어드립니다.  게임 개발/앱 개발/프로그래밍을 하신다면 꼭 들으셔야 합니다. 기초를 소홀히 한다면 따라 하기식 개발만 배운 사람은 튜토리얼에 나온 개발 이외에는 개발이 어렵습니다.     🤷🏻‍♀️ 게임을 만들고 싶나요? 🤷🏻‍♀️ 구상만 한 앱 아이디어가 있나요? 🤷🏻‍♀️ 프로그래밍을 하고 싶은데 어디서부터 시작해야 할지 막막하시나요?  제가 학원 강사로 재직했을 당시, 강의 만족도는 항상 높았습니다. 또한 수업 내용에 대해서 컴플레인을 단, 한 번도 받아본 적 없습니다. 그 이유는 실제 꼭 필요한 내용만 담아 만들고 싶은 프로그램을 손쉽게 만들 수 있도록 튼튼한 기초를 강의했기 때문입니다.    저는 유튜버로 과학/IT 기술에 대한 콘텐츠를 만들며, 프로그래밍 결과물을 유튜브에서 공유하고 있습니다.  🖥 경력 저는 현업에서 10년간 개발자로 활동하고 있습니다. SI 분야에서 업무를 진행했으며, 현재 인디 게임 개발 회사에서 게임 개발자로 5년 동안 업무를 수행하고 있습니다. 또한 4년동안 게임프로그래밍, 애플리케이션 프로그래밍 관련 강사 경력이 있습니다.    따라 하기식 강의를 듣고 왔는데, 강의 내용 외에 자신이 원하는 개발을 하기 힘든 분들이 많습니다. 이는 대부분 프로그래밍 언어의 기초지식을 쌓지 않고 단순히 따라 하면서 배웠기 때문입니다.  ✅ 요즘 한창 핫한 Python, 혹은 웹 개발, 앱 개발이나 게임 개발을 목표로 하시더라도 이 기초 강의는 꼭 수강하시는 것을 추천합니다. 기초가 튼튼한 개발자가 오랫동안 안전하고 튼튼한 개발을 할 수 있습니다. 건물을 지을 때에도 튼튼한 기초공사가 되어있어야만 높은 건물을 올릴 수 있듯. 개발도 마찬가지 입니다.  ✅ 범용적인 프로그래밍 지식을 원한다면 꼭 필요한 강의입니다. 이 클래스는 흔히 어렵다고 생각하는 C / C++을 이용한 강의 입니다. 하지만 본 강의는 C / C++ 에서 가장 중요한 부분만을 추려서 어렵지 않게 전달하며, 강의를 완료하게 되면 C / C++에 대한 기초 지식을 쌓게 되고, 이 C / C++ 기초 지식은 그 자체만으로 다른 언어로 프로그래밍을 할 때, 많은 도움이 되는 내용입니다  ✅ 대학교에서 전공 강의를 따라가기 어려운 분들에게도 적합합니다. 전공 수업은 기본적으로 많은 내용을 한 번에 알려주기 때문에 교수님의 실력에 관계없이 대학 수업 자체에 어려움을 호소하는 분들이 많습니다. 이 분들을 위해 핵심, 중요한 부분 위주로 알려드릴 수 있어 훨씬 더 빠른 프로그래밍 습득이 가능합니다.    🎲 Unity, Unreal, Cocos2d-x 등 게임 엔진으로 입문하기 앞서 수강하길 권장드립니다.  게임이라는것 은 초당 60~144 회의 갱신이 일어나는 시뮬레이션 공간입니다. 1초에 60번, 정해진 시뮬레이션 공간 안의 개체들은 CPU에 의해 끊임없이 연산되어야 하고, 해당 데이터를 바탕으로 화면에 렌더링 해야 하는 개체들은 끊임없이 GPU에 의해 연산됩니다.  때문에 가장 퍼포먼스가 좋은 프로그래밍 언어로 개발되는 경우가 많으며, 캐주얼 게임이 아닌 이상 대부분의 고사양 게임은 C++, C# 등 퍼포먼스가 검증된 언어로 개발하게 됩니다.  즉, 게임 개발을 위해 C / C++ 언어를 통해 프로그래밍의 기초를 쌓게 된다면 어떤 게임을 만들어도 더더욱 퍼포먼스가 좋은 게임을 만들 수 있으며, 게임 개발에 대한 지식도 쌓을 수 있습니다.    🖥 본 클래스는 실습 중심의 커리큘럼으로 구성되어 있습니다. 극 초반부를 제외한 대부분의 챕터는 1개 혹은 2개의 연습 프로그래밍이 출제되며, 연습 프로그래밍은 다음 챕터에서 함께 프로그래밍을 통해 마스터하게 됩니다. 1️⃣ 기초 C 프로그래밍 이 챕터에서는 기본적인 C 언어의 활용방법을 배우게 됩니다. C 언어의 활용을 배우면서 컴퓨터 프로그램의 기초적인 구조를 알게 됩니다. 2️⃣ 심화 C 프로그래밍 포인터가 어려우시다고요? 이 챕터에서는 일반적으로 C 혹은 프로그래밍 언어를 배우는 분들이 가장 이해하기 어려운 포인터에 대한 개념을 쉽게 풀어내는 강의가 됩니다. 여기서 배운 내용을 바탕으로 콘솔에서 동작하는 간단한 MBTI 테스트를 만들어 보게 됩니다. 3️⃣ 기초 C++ 프로그래밍 - 객체지향 첫걸음 이 챕터에서는 클래스와 객체지향에 대해서 간단하게 알아보게 됩니다. 객체지향이라고 하면 굉장히 어렵다고 생각하는 경향이 있는데요, 객체지향에서 알아둬야 하는 아주 기본적인 내용을 다루고 있으며, 다른 프로그래밍 언어에서도 흔하게 찾아볼 수 있는 내용을 위주로 강의가 진행되므로 개발자를 목표로 한다면 꼭 알아야 하는 내용이라고 할 수 있겠습니다. 여기서 배운 내용을 바탕으로 간단한 콘솔 테트리스 게임을 만들어 보게 됩니다. 4️⃣ 심화 C++ 프로그래밍 - 고급 프로그래밍을 위해 이 챕터에서는 C++의 컴파일 방법과 여러 가지 C++에서 활용하는 추가적인 개념을 배우게 됩니다. 여기서 배운 내용을 바탕으로 영문 타자 연습 프로그램을 만들어보게 됩니다.   콘솔 프로그래밍은 일반인이 보기에는 혹은 개발 초심자가 보기에 가장 재미없고 따분한 프로그래밍처럼 보일 수 있습니다. 눈이 즐거운 GUI 환경이 없기 때문일 것 입니다.  하지만 콘솔 프로그래밍을 제대로 다룰 수 있어야, 멋진 GUI도 그리고 재미있는 게임도 만들 수 있습니다.  5일\n09\n:\n33\n:\n42\n남음  클래스101 | 세상의 모든 클래스, 클래스101                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# 1     C/C++ 입문 클래스: https://class101.app/e/lala_ccc_class 그렇지 않다면 자신의 C/C++ 실력이 충분히 진행가능한 레벨이 되어야만 이 클래스를 따라올 수 있습니다.  이 클래스는 게임개발 기초 미니 클래스 입니다. 본 클래스는 Cocos2d-x 를 이용한 게임개발로 이루어지며 C/C++ 과정을 이수한 분들이 C/C++의 활용 혹은 C/C++을 이용한 게임 개발의 입문을 돕기 위해 만들어진 클래스입니다.  Cocos2d-x 는 C / C++ 기반 게임 엔진으로서 모바일 게임 개발에 최적화 되어 있으며, macOS, Windows, Android, iOS 기반 게임을 만들수도 있는 범용 멀티플랫폼 엔진입니다.   🤷🏻‍♀️ C / C++의 기초는 배웠지만, 실전 프로그래밍과 활용을 배우고 싶으신가요? 🤷🏻‍♀️ 혹시 게임 프로그래밍을 배우고 싶으신가요?  Cocos2d-x 는 C++ 기반으로 이루어진 엔진으로서 전 세계적으로 캐주얼 게임 개발로 많이 사용되고 있는 게임 엔진입니다. 또한 여러분들은 이 클래스를 통해 게임개발뿐만이 아닌 C++ 의 중고급 활용과 실전 프로그래밍에 관해 공부할 수 있게 됩니다. C++는 단연코 그 어떤 언어보다 가장 좋은 퍼포먼스를 보장하는 프로그래밍 언어이며, 이 프로그래밍 언어로 만들어진 Cocos2d-x는 2D 캐주얼 게임에서 가장 좋은 퍼포먼스와 가장 가벼운 성능을 제공합니다    저는 유튜버로 과학/IT 기술에 대한 콘텐츠를 만들며, 프로그래밍 결과물을 유튜브에서 공유하고 있습니다.  🖥 경력 저는 현업에서 10년간 개발자로 활동하고 있습니다. SI 분야에서 업무를 진행했으며, 현재 인디 게임 개발 회사에서 게임 개발자로 5년 동안 업무를 수행하고 있습니다. 또한 4년 동안 게임프로그래밍, 애플리케이션 프로그래밍 관련 강사 경력이 있습니다.   게임 개발을 공부하기 위해서는 여러 가지 빌드업이 있습니다. 유니티를 배우거나, 언리얼 엔진을 배우는 것, 그리고 DirectX를 이용해 바닥부터 게임엔진을 만들어가는 것이죠. 하지만 C/C++ 의 기초를 배우셨다면, 바닥부터 게임엔진을 만드는 것은 별로 추천해 드리고 싶지 않습니다.  DirectX를 이용해 바닥부터 게임을 만들게 되면 물론 좋은 경험이 될 수는 있으나. 여러 가지 시행착오를 겪게 되고, 급기야는 포기하는 학생이 있을 수 있으며, 정말 자잘한 것 하나하나 제작해내야 하므로 너무나 많은 고생을 하게 됩니다. 만들어낸 게임 프로그램도 여러분의 스마트폰이나 맥에서 구동을 시킬 수도 없죠. 하지만 Cocos2d-x는 C/C++의 기초를 이용해서 게임을 만들면서, 주요 플랫폼에 대한 검증과 대응이 되어 있는 게임엔진 입니다.  때문에 C/C++ 을 이용해서 간단한 캐주얼 게임을 만들기 위해서나, 게임 개발 입문에 대해서 공부하기에는 Cocos2d-x 가 적당히 어렵고 적당히 쉽기 때문에 적합하다고 말씀드릴 수 있습니다.  ✅ 유니티나 언리얼을 이용해 게임개발을 하기로 목표를 잡으셨더라도 Cocos2d-x 로 게임개발을 해 본 경험은 그 자체로 큰 자산이 될 수 있습니다. Cocos2d-x 는 프로젝트 설정 및 빌드, 그리고 C++ 상속 / STL 에 대한 포괄적인 이해를 해야만 게임을 만들어낼 수 있는 정말 C++ 친화적인 게임 엔진입니다.  ✅ 모든 게임엔진의 기본적인 골자는 모두 같습니다. Cocos2d-x 에서 배운 내용이 Unity 나 Unreal에서 그대로 이어지게 됩니다. 모든 개발 언어가 사투리 관계에 있듯, 모든 게임 엔진도 사실상 거기서 거기입니다. 사투리관계에 있다고 볼 수 있습니다.  현대 게임엔진이라는 것 또한 프로그래밍 언어처럼 어느 정도 정형화가 되어있기 때문에 Cocos2d-x 게임엔진 공부는 어떤 게임엔진을 다룬다고 하더라도 추후 게임개발에 큰 자산이 될 수 있습니다.    🎲 Cocos2d-x 는 게임개발 엔진이지만 C++의 범용적인 활용을 할 수 없다면 절대 개발을 할 수 없는 게임엔진 입니다.  이 진입장벽 때문에 많은 사람들이 Unity 를 활용한 쉬운 게임 개발로 넘어가게 됩니다.  하지만 이 진입장벽을 넘어 공부하게 되면 C++를 활용하여, 게임개발의 원리를 바닥부터 배울 수 있으며,  이 저수준에 대한 이해와 게임개발에 대한 이해는 추후 어떠한 게임엔진으로 개발을 하게 되어도 여러분의 개발에 도움이 될 것이라고 확신합니다.  또한 Cocos2d-x는 완전 무료 오픈소스이며, 다른 AAA급 게임엔진과는 다르게 캐주얼 게임에 맞춰진 간단한 엔진이기 때문에 이 오픈소스의 소스코드를 하나하나 직접 뜯어보면서 공부할 수 있다는 엄청난 장점도 있습니다.  Unreal 게임엔진 또한 오픈소스로 공개되어 있으나. 해당 오픈소스의 소스코드가 너무 방대하고 해당 오픈소스를 빌드하기 위해 알아야 할 선행지식이 너무나도 많기에 해당 소스코드를 뜯어보면서 공부한다는것은 초심자에게는 말도 안 되는 일 입니다.  하지만 Cocos2d-x는 적당한 수준의 소스코드 양과, 적당한 수준의 엔진 크기로 인해 정말 소스코드를 뜯어보면서 공부하기에 매우 좋습니다.     🖥 본 클래스는 게임을 만들어내는데 중점을 두고 있습니다. 때문에 1챕터에서는 간단하게 게임엔진에 대한 소개를, 개념에 대한 소개를 먼저 하게 되고, 2챕터, 3챕터에서 게임을 하나씩 만들어내는 따라하기식 강의를 들으실 수 있습니다. 이 강의에서 여러분은 탑다운 방식의 슈팅게임과 3Match 형태의 블록 퍼즐 게임 개발에 대해 배우게 됩니다. 1️⃣ Cocos2d-x 기본 개념 이 챕터에서는 Cocos2d-x의 기본 개념에 대해 배우게 됩니다. 이 개념은 대부분의 게임 엔진에서 활용하고 있는 개념이며, 이 개념을 이용해 2챕터에서 본격적인 게임 개발을 시작하게 됩니다. 또한 이 챕터에서 현업 개발자가 개발을 할 때 자료를 참고하는 방법이나, 실전 프로그래밍에서의 개발에 대한 원칙을 알아볼 수 있습니다. 2️⃣ 3-Match 비주얼드 게임 개발 (애니팡) 이 챕터에서는 CC0(무료 리소스)를 활용해 애니팡 형태의 게임을 만들어보게 됩니다. 만들어진 게임을 Android 로 포팅하여 자신의 휴대폰에 집어넣어보는 과정도 포함됩니다. 이 챕터에서는 간단한 애니메이션, 사용자 입력에 대응하기, 간단한 UI 제작, 사운드 효과 지정, 퍼즐게임 알고리즘 등에 대해 알아보게 되며, 기본적으로 어떻게 Opensource의 소스코드를 확인하면서 개발하는지 등을 배우게 됩니다. 3️⃣ 탑 다운 슈팅게임 개발 이 챕터에서는 CC0(무료 리소스)를 활용해 탑 다운 방식의 슈팅게임을 같이 개발해보게 됩니다. 적 개체의 움직임 방법과 탄막, 애니메이션 지정방법, 충돌처리 등 게임 개발에 관한 기본적인 내용에 대해 알아보게 됩니다. 이를 통해 기본 액션게임 혹은 fps 게임들이 어떤 방식으로 동작하는지에 대한 원리와 게임세계에 대한 이해를 할 수 있습니다. 이 엔진을 사용하여 만들어진 게임은 다음과 같습니다. 모두의 마블 쿠키런 에픽세븐 리니지 M 지오메트리 대시  국내에는 유니티에 밀려 많이 사용되는 엔진은 아니지만 경쟁력이 있고 잘 만들어진 여러 게임이 존재하는 양질의 게임 엔진이며  C++기반 엔진이기 때문에 게임에서의 퍼포먼스는 단언코 유니티보다 더 좋습니다.  23\n:\n33\n:\n30\n남음  클래스101 | 세상의 모든 클래스, 클래스101                                                                                                                                                                                                                                                                                                                                                                                                              ...
# 2                1) 대체 뭐부터 개발해야할 지 모르겠어요. 원래 처음 개발을 배우면, 뭐부터 시작할 지 모르기 때문에 막막합니다. 개발 방향성이 없으니 그걸 잡아주는 사람이 필요해요. 2) 자바스크립트로 별찍기만 하고있어요. 개발에 대한 큰 그림이나 감이 없기 때문입니다. 저런거만 하려고 우리가 개발을 고생해가며 배운게 아닙니다. 3) 기껏 열심히했는데, 에러/버그에서 막혔어요. 이 부분 역시 가이드할 수 있는 사람을 만나지 못해서 그렇습니다. 매번 물어보기 미안해서 그럴수도 있구요. 4) 강의들을 찾아봤는데, 다들 너무 딥해서 어려워요. 개발은 그때그때 필요한 것만 먼저 배우면 됩니다. 결국 딥한 개발은 나중에 배우면 되는데, 그걸 구분해내는 눈이 없으니 문제가 됩니다.   개발에 대한 큰 그림과 방향성을 익힐 수 있도록 돕겠습니다. 코칭을 통해 에러/버그 역시 해결할 수 있도록 돕겠습니다.  또한 딥한 개발과 지금 당장 필요한 개발을 구분할 수 있는 눈을 갖도록 돕고, 정말 필요한 것만 쏙쏙 골라서 알려 드릴게요.  디자인 적으로 이쁜 웹 사이트는 웹 개발 전체 그림을 본다음에 디벨롭 해도 늦지 않습니다. 웹 개발 뿌리부터 같이 빠르게 한번 훑어 보시죠!   전체 단과는 3가지 반으로 구성되어 있습니다.   여러분이 웹 서비스에 대한 기초와 프론트엔드(화면), 백엔드(서버)에 대해 이해하고 개발하고 싶은 단계라면 이번에 오픈된 1교시를 수강하세요.  👍 첫번째로 만들어 볼 것! TODO 리스트    웹 개발자 단과반 1교시에서는 개발 전 워밍업, 웹과 서버에 대한 이해, HTML, CSS로 만드는 메인화면과 디테일화면, JS(자바스크립트)까지 배울 수 있습니다. 이렇게 배운 내용을 토대로 TODO 리스트를 만들어 볼 거에요.  ✌️ 두번째로 만들어 볼 것! 영화 리뷰 플랫폼 최종적으로 영화 플랫폼까지 만들어봅니다. 가능합니다!   1교시에서 배운 전체 내용을 활용하여 30분만에 영화 커뮤니티 플랫폼을 만들어 봅니다. 메인화면을 만들고, 영화별 모달 댓글창을 만드는 과정 등이 포함됩니다. 빠르게 이쁜 웹 사이트를 만들 수 있는 부트스트랩이란, 디자인 도구를 사용하여 직접 만들어 완성합니다!  그 후 영화 API와 댓글 달기 기능 등을 추가하는 것으로 마무리됩니다. (API는 2교시때 배울 서버 내용 맛보기 입니다 :)  API는 아주 간단히 말해서, 내 컴퓨터가 아닌 외부의 데이터를 가져올 때 요청하는 규칙이라고 생각하시면 됩니다.    이렇게 정해진 요청과 응답의 '쌍'으로, 특정 데이터를 내 컴퓨터와 프로젝트로 가져오는 게 바로 API라고 볼 수 있습니다.  어쨌든 우리는 이 API 규칙을 이용해서 영화 커뮤니티 플랫폼을 만들 때 외부 영화 데이터를 불러올 수 있는 것이죠 :)   여러분이 트레이닝을 마치게 되면, 이제는 개발에 필요한 지식을 '그때그때 찾아볼 수 있는 능력'이 길러질 겁니다. 진짜로 성장할 수 있는 포인트는 배운 것을 활용하는 데서 옵니다. 여러분이 마음껏 지식을 확장할 수 있도록 '개발근육'을 길러 드리겠습니다!     이처럼 차근차근 트레이닝하면서 완성된 웹 개발자로 나아가면 됩니다. 두려워하지 마세요. 필요한 걸 하나씩 채워가는, 꾸준히 학습하는 개발자가 되시길 응원합니다.  1교시: HTML, CSS, JS 프론트엔드 교시! 클래스에서 뵙겠습니다! 23\n:\n33\n:\n16\n남음  클래스101 | 세상의 모든 클래스, 클래스101                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ...
# 3      📍대체 뭐부터 개발해야 할지 모르겠어요. 원래 처음 개발을 배우면, 뭐부터 시작할지 모르기 때문에 막막합니다. 개발 방향성이 없으니 그걸 잡아주는 사람이 필요해요. 📍자바스크립트로 별찍기만 하고 있어요. 개발에 대한 큰 그림이나 감이 없기 때문입니다. 저런 거만 하려고 우리가 개발을 고생해가며 배운 게 아닙니다. 📍기껏 열심히 했는데, 에러/버그에서 막혔어요. 이 부분 역시 가이드 할 수 있는 사람을 만나지 못해서 그렇습니다. 매번 물어보기 미안해서 그럴 수도 있고요. 📍강의를 찾아봤는데, 다들 너무 딥해서 어려워요. 개발은 그때그때 필요한 것만 먼저 배우면 됩니다. 결국 딥한 개발은 나중에 배우면 되는데, 그걸 구분해내는 눈이 없으니 문제가 됩니다.   📍개발자 사관학교에서 트레이닝 받으세요. 개발에 대한 큰 그림과 방향성을 익힐 수 있도록 돕겠습니다. 코칭을 통해 에러/버그 역시 해결할 수 있도록 돕겠습니다. 또한 딥한 개발과 지금 당장 필요한 개발을 구분할 수 있는 눈을 갖도록 돕고, 정말 필요한 것만 쏙쏙 골라서 알려 드릴게요.  📍사관학교식 강의안 제공해드려요    📍필요한 과목만 수강하세요. 전체 단과는 3가지 반으로 구성되어 있습니다.   각각의 기본 문법을 학습하고, 빠르게 속성으로 영화리뷰 페이지를 만들어보는 과정이었습니다. 거기에 API로 영화와 댓글 기능 등을 연결했었죠. 이번 2교시: 백엔드 단과반에서도 이 내용을 복습할 예정입니다. 1챕터에서 빠르게 HTML, CSS, JS 속성 강좌를 제공하고, 코드도 제공해드릴게요. (만약 1교시 수업이 듣고 싶은 분들은 클릭!)   1교시에서 HTML, CSS, JS를 배우면서 웹 개발에 대한 기초체력을 길렀으니, 이번 2교시에서는 자바스크립트로 서버를 직접 만들어 볼 차례입니다.   이번 2교시를 들으면, 백엔드와 서버에 대한 생각이 완전히 바뀌게 됩니다. 어떻게 그게 가능하냐고요? 여러분의 노트북이 곧 서버가 되고, 웹 서비스를 움직이게 되기 때문입니다. 개발자 사관학교에서 추구하는 방향성은 늘 그래왔듯이, 큰 그림을 그리는 것부터 서버를 차근차근 배워보도록 합시다.   우리는 자바스크립트로 서버를 만들고, 크롤링 및 업무 자동화까지 배울 수 있습니다. 벌써 HTML, CSS, JS를 까먹으셨다고요? 괜찮습니다. 자바스크립트로 서버를 배우는 시간이기 때문에, 중간중간 복습을 통해 실습을 쉽게 따라 할 수 있습니다. 걱정하지 마세요!   HTML, CSS를 공부했다면 한 번쯤은 시도했을 법한 투두 리스트, 영화 리뷰 사이트 등이 있습니다. 저희는 이걸 이용해서 실제 사람들이 사용까지 할 수 있는 '서버'가 붙은 하나의 웹서비스로 구축할 예정입니다. (*영화 리뷰 사이트 HTML, CSS 코드를 제공하니, 이 부분 역시 걱정 마세요!)     한 번 예시를 살펴볼까요?   [ 야후 파이낸스 크롤링을 통해 투자할만한 회사를 찾아볼 수 있어요. ]  [ 엑셀로 업무 자동화를 구현하면, 반복 작업 속도가 올라가고 워라밸이 생기죠. ] 어쨌든 모든 기능은 자바스크립트 서버로 구현하고, 저장은 MySQL로 가능합니다. 진짜 재미있고 유용한 기술은 지금부터입니다. 여러분이 만약 HTML, CSS에 너무 빠져있다고 생각된다면, 서버부터 배우는 것 또한 추천합니다. 개발 공부는 재미를 잃지 않고 이어가야 합니다.    API는 아주 간단히 말해서, 내 컴퓨터가 아닌 외부의 데이터를 가져올 때 요청하는 규칙이라고 생각하시면 됩니다.   이렇게 정해진 요청과 응답의 '쌍'으로, 특정 데이터를 내 컴퓨터와 프로젝트로 가져오는 게 바로 API라고 볼 수 있습니다. 어쨌든 우리는 이 API 규칙을 이용해서 영화 커뮤니티 플랫폼을 만들 때 외부 영화 데이터를 불러올 수 있는 것이죠 :)  중요한건 이렇게 쉽게 우린 서버 개념들을 배웁니다 :)   📍매번 전문가에게 물어볼 수는 없으니까. 여러분이 트레이닝을 마치게 되면, 이제는 개발에 필요한 지식을 '그때그때 찾아볼 수 있는 능력'이 길러질 겁니다. 진짜로 성장할 수 있는 포인트는 배운 것을 활용하는 데서 옵니다. 여러분이 마음껏 지식을 확장할 수 있도록 '개발 근육'을 길러 드리겠습니다!     이처럼 차근차근 트레이닝하면서 완성된 웹 개발자로 나아가면 됩니다. 두려워하지 마세요. 필요한 걸 하나씩 채워가는, 꾸준히 학습하는 개발자가 되시길 응원합니다.  23\n:\n33\n:\n03\n남음  클래스101 | 세상의 모든 클래스, 클래스101                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# 4       웹 사이트 배포와 관련 개념 아마존 웹 서비스 Node.js 예제 코드로 서버를 직접 배포!     HTML, CSS 학습에서 멈추실 건가요? 웹 개발을 공부했다면, 배포까지 해보셔야 합니다. 배포하지 않은 웹 사이트는 내 컴퓨터에서만 확인할 수 있는 하나의 파일에 불과합니다. 여기서 말하는 '배포'란, 웹사이트 'class101.net' 주소가 있으면 어느 브라우저에 입력을 해도 클래스101에 들어올 수 있는 것처럼, 전 세계 사람들에게 나만의 도메인을 만들어 홈페이지를 공개하는 것을 말합니다.  웹 사이트 개발과 배포만큼 중요한 것은 '내 사이트에 누가 오는가? 왜 오는가?'입니다. 사용자의 행동을 분석할 수 있는 구글 애널리틱스 코드를 심어 1) 사람들이 무엇을 통해 웹사이트에 접속하는지, 2) 무엇을 보고 이탈하는지, 3) 얼마나 오래 머무는지 등을 직접 확인하고 분석해봅니다.  📍 FAQ 1. HTML, CSS를 배웠습니다. 사이트를 만들 수 있나요? - 가장 많이 듣는 질문입니다. 서버, 즉 백엔드 개발을 하지 않았는데 사이트가 될 수 있는가? 네, 될 수 있습니다. 정적파일(HTML, CSS)만 가지고도 도메인을 갖는 사이트가 될 수 있습니다. 📍 FAQ 2. Node.js도 배웠습니다. 배포하고 싶어요! - 본 클래스를 들으면 AWS(아마존 웹 서비스)를 통해 배포할 수 있습니다. 여러분들이 열심히 공부한 Node.js 서버를 이용한 웹 사이트를 전 세계 사람들과 공유해봐요!   여러분들이 프론트와 백엔드를 공부해보셨다면, 반드시 이를 배포해보셔야 합니다. 배포함으로써 도멘인을 갖는 웹사이트를 만들어, 내 페이지를 세상에 알리고 분석까지 경험해봅시다. 단순히 프론트엔드 - 백엔드를 배우는 것만을 넘어서, 배포까지 경험해보며 풀스택 개발자에 한 발자국 더 가까워질 수 있습니다.  📍 전체 단과는 세 개의 반으로 구성되어 있습니다.  "어려워 보이는데 할 수 있겠죠?" 1,2교시를 저랑 같이 공부하셨던 분들은 아시겠지만, 오!해! 입니다. 이번 3교시는 더더욱 쉬울 겁니다. 마치 조립 설명서를 보면서 하나하나 맞춰가듯이 천천히 따라오시면 어느새 도메인을 가진 "내 웹사이트"를 갖게 됩니다.     1️⃣ IP, 도메인에 대한 개념을 배우고 아마존 웹서비스에선 어떤 기능들을 사용할 수 있는 지 알아봅니다. 2️⃣ HTML,CSS 파일을 드립니다. 이 파일만 가지고 서버 없이도 회사 소개 페이지정돈 도메인을 갖는 웹사이트 배포를 바로 해봅니다. 📍 이런 웹사이트 코드를 드려요!  3️⃣ Node.js 프로젝트 코드를 드립니다! 아주 잠시 리뷰 후, 아마존 웹 서비스 기능들을 사용하여 서버를 같이 구축해봅니다.  4️⃣ 도메인을 구매합니다. 2,3에서 공부하여 얻은 IP 주소에 도메인을 연결해봅니다. 5️⃣ 끝나지 않았어요! 구글 애널리틱스 코드를 여러분 웹 사이트에 심고 어디서 유저들이 들어오는 지 분석해봅니다       📍 개발자 사관학교에서 실습형 개발PT 시작하세요! 더 이상 재미없게 개발 공부하지 마세요! 처음부터 끝까지 실습형 개발 공부로, 직접 완성본을 만들어가며 배울 수 있습니다. 현업 개발자들이 사용해도 전혀 무방한 기초 코드 모두 제공해드리니, 나중에 이 '코드'로 여러분만의 프로젝트 또한 쉽게 만들 수 있습니다.  키트 미개봉 시, 1월 12일까지 전액 환불 보장 클래스101 | 세상의 모든 클래스, 클래스101                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 235     기술번역과 다른 번역 분야와의 차이점 기술번역업계가 좋아하는 번역 스타일 기술번역의 다양한 분야    아침에 iPhone 알람 소리에 잠자리에서 일어나 지하철을 타고, 버스를 타고 출근합니다. 출근하는 길에 Facebook에 들어가 친구들, 지인들 소식도 듣고 간밤에 올라온 새로운 소식을 확인합니다. 출근해서는 다양한 업무를 처리하며 Google을 이용해 각종 정보를 검색합니다. 업무 관련 정보뿐만 아니라 상품, 서비스, 맛집 등의 일상적인 정보도 검색하죠. 길고도 긴 업무를 마치고 집에 돌아오면 Netflix에서 어제 보다 만 드라마를 시청하며 하루의 피곤을 씻어 봅니다. 여러분의 일상도 비슷하지 않으신가요? 이렇게 세계적인 빅테크 기업에서 제공하는 제품과 서비스는 이제 우리 일상에서는 없어서는 안 될 중요한 요소가 되었습니다. 하지만 혹시 생각해 보셨나요? 이런 제품과 서비스가 모두 한글로 제공되고 있다는 것, 처음에는 영어로 제공되었을 이 제품과 서비스의 인터페이스가 모두 누군가의 손을 거쳐 한글화되었다는 것. 바로 저와 같은 기술 번역가들이 하는 일입니다.   맞습니다. 번역가의 이름이 찍혀 번역서가 출간되는 출판번역이나 크레딧에 번역가의 이름이 표시되는 영상번역과 달리 기술번역을 통해 생산되는 수많은 컨텐츠에는 번역가의 이름이 표시되지 않습니다. 모두 고객 혹은 에이전시와의 NDA(Non-Disclosure Agreement) 때문입니다. 기업들은 내부에서 개발한 기술이 곧 자산이지요. 신기술은 모두 현지화를 거쳐 출시되는데, 번역 과정에서 혹시라도 새로 개발한 기술이 유출된다면 기업으로서는 막대한 손실이 아닐 수 없습니다. 따라서 기술번역업계의 프리랜서들은 자신이 어떤 기업의 어떤 프로젝트에 참여하고 있는지 외부에 알릴 수 없습니다. 이 업계가 잘 알려지지 않은 이유이기도 합니다. 당장 우리가 매일 쓰는 Windows 운영체제만 보더라도 그 수많은 UI를 누가 번역 했는지가 표시되어 있지 않지요. 그렇기 때문에 우리는 평소에 이러한 소프트웨어 프로그램이 누군가의 손을 거쳐 한글화 되었다는 것을 인식하지 못합니다. 하지만 이렇게 한글화된 콘텐츠는 지금도 쏟아져 나오고 있고 새로운 제품과 서비스를 찾는 한국 사람들이 있는 한, 한글화에 대한 수요는 사라지지 않을 것입니다.   기술번역을 합니다. 이름만 들으면 알 만한 빅테크 기업들의 다양한 프로젝트에 참가해 22년째 번역, 리뷰, LQA(Language Quality Assurance) 일을 하고 있습니다. 또한 온라인 번역 아카데미를 운영하며 다년간 쌓은 번역 기술과 노하우를 번역가 지망생들에게 가르치고 있습니다.  기술번역업계에 몸담은 지 20년이 넘었지만 여전히 번역 일로 바쁘게 보내고 있습니다. 제가 기술번역을 자신있게 추천드리는 이유도 여기에 있습니다. 저의 LinkedIn 계정과 이메일에는 프로젝트 참여 의사를 묻는 에이전시 리소싱 담당자의 메시지가 쌓여 있습니다. 여러분도 에이전시에서 찾는 번역가가 되는 기쁨을 누려 보셨으면 좋겠습니다!    "기계번역이 발전하고 있는데 기술번역가로 먹고 살 수 있을까요?" 많은 분들이 궁금해 하시는 내용이지요. 결론부터 말씀드리자면 먹고 살 수 있습니다. 단, 기계번역과 비슷한 수준의 그저 그런 번역 실력이 아닌 뛰어난 번역 실력을 갖추고 있어야 합니다. 실제로 이제 단순한 텍스트는 많은 부분 기계번역에 의존하고 있습니다. 하지만 아직 사람처럼 유려하고 세련된 문장을 만들 수 있는 수준이 아니기 때문에 중요도가 높은 문서일수록 사람이 개입해야 합니다. 특히 판매, 수익과 직결되는 마케팅 문서들은 여전히 전적으로 사람의 번역에 의존하고 있습니다.   우리는 매일 스마트폰을 통해, 인터넷을 통해 유수의 글로벌 기업에서 생산하는 수많은 한글화된 제품과 서비스, 콘텐츠를 소비하고 있습니다. 그만큼 한글화에 대한 수요는 높다고 할 수 있습니다. 특히 마케팅 문서를 번역할 수 있는 능력을 갖춘 번역가를 찾는 기업들이 많습니다. 아무래도 마케팅의 특성상 타겟층 고객을 사로잡을 수 있는 호소력 있는 문장력과 표현력으로 메시지를 전달할 수 있어야 하기 때문이지요.  클래스도 바로 이런 점들을 염두에 두고 구성했답니다! 기본적인 번역 기술은 물론이고 IT 문서의 유형에 따라 이런 번역 기술들을 어떻게 활용하고 적용할지를 배웁니다.  - 전천후 번역 기술 익히기 - 문서 유형에 따른 번역 스타일 이해하기 - 번역 테스트에 적합한 번역 스타일 파악하기  아울러 이런 번역 기술을 가지고 번역 업계로 진출할 수 있는 팁까지 알려 드립니다.    아무래도 선망하는 빅테크 기업들의 최신 기술과 콘텐츠를 미리 만나볼 수 있다는 점이 아닐까 싶어요. 신제품 혹은 새로운 기능이 시장에 출시되기 전에 내가 먼저 번역을 하게 되니까요. 또 빅테크 기업의 내부 담당자와 커뮤니케이션을 하면서 그들의 문화를 경험할 수 있다는 점, 그리고 장기적으로 협업하다 보면 내가 하청을 받던 빅테크 기업으로 취직하게 될 수도 있다는 점이 매력이죠. 실제로 저도 이런 오퍼를 종종 받지만 저는 프리랜서의 삶이 더 좋아 고사하고 있지만요. 무엇보다 경력이 쌓이다 보면 고정 고객이 생기게 되는데 이 수준에 오르면 한 고객의 프로젝트만으로도 충분히 안정적인 생활을 할 수 있게 됩니다. 프로젝트 하나는 좀 아쉽다 하는 경우 다른 에이전시를 통해 프로젝트를 하나 더 하는 식으로 안전 장치를 두는 프리랜서도 많습니다. 어쨌거나 책이 한 권 끝나면 다음 책을 찾아 계약을 해야 하는 출판번역과 달리 기술번역은 일단 한 고객의 프로젝트를 시작하면 굉장히 오랜 기간 일하게 됩니다. 저도 현재 진행 중인 G사 고객의 프로젝트는 10년 가까이 해오고 있답니다.    걱정 마세요. 번역 업계에 대한 이해가 부족한 상태에서는 어느 번역 업계가 나에게 맞을지 확신할 수 없는 게 당연합니다. 이 클래스에서는 모든 번역 분야 진출에 두루 활용할 수 있는 기본적인 번역 기술 또한 배웁니다. 앞서 기술번역업계에서 경쟁력을 갖추려면 단순한 텍스트보다는 깊이 있고 수준 높은 콘텐츠를 세련되고 깔끔한 문장으로 옮길 수 있어야 한다고 말씀드렸지요? 그러기 위해서는, 원문을 이해하는 능력은 당연히 중요하고, 무엇보다 우리말을 제대로 쓸 줄 알아야 합니다. These shoes hurt my feet.라는 문장을 ‘이 신발은 나의 발을 아프게 해.’가 아니라 ‘이 신발은 발이 아파.’라는 문장으로 옮길 수 있어야 한다는 것입니다. 번역 냄새가 나지 않고 처음부터 우리나라 사람이 우리말도 쓴 듯한 문장을 만들려면 영어와 우리말의 차이를 바로 알고 우리말의 특성을 살릴 수 있는 번역문을 만들어야 합니다. 이 클래스에서는 그런 번역 기술을 배웁니다. 5일\n08\n:\n30\n:\n18\n남음  클래스101 | 세상의 모든 클래스, 클래스101                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
# 236   패널 씨어터를 활용한 해님달님 인형극 막대인형 만들기 책표지 꾸미기 인물과 무대연출하기 관절인형 만들기 다양한 효과 만들기 감정 주사위와 스토리 주사위 만들기 내가 만든 인형극장 패널 씨어터 인형극 경험하기 막대인형 만들기 직접 인물과 무대 연출하기       아이를 키우면서 책 읽기의 중요성에 대해 얼마나 많이 들으셨나요? "책은 마음의 양식"이라는 오래된 표어부터 "두뇌가 폭발적으로 성장하는 영유아기가 책육아의 골든 타임"이라는 전문가의 의견까지, 그 누구보다 부모님들께서 독서의 중요성을 잘 알고 계실 거라 생각합니다.  하지만 '독서 습관'의 골든타임에 대해서는 혹시 알고 계신가요? 전문가의 말에 따르면, 뇌 발달이 거의 완성돼 성인과 같은 수준이 되는 만 12세 이전까지는 꼭 독서 습관을 들여야 합니다.   위 2020년 독서 실태 조사에서도 보이다시피, 대부분의 아이들은 초등학교 졸업 후 책에 대한 관심도가 하락하는 경향을 보였습니다. 하지만 독서를 습관화한 아이들은 고등학생이 되어도 꾸준히 책에 대해 흥미를 보인 걸 알 수 있습니다.   영유아기까지는 부모의 책 읽기를 듣는 것만으로도 창의력 향상 등 독서 효과를 경험할 수 있지만, 언제까지나 부모가 다 해줄 수는 없는 노릇이죠. 어렸을 때 자전거 타던 습관을 익혀두면 오랜 시간 타지 않더라고 언제든 돌아갈 수 있는 것처럼, 독서는 우리 아이의 습관이 되어야 합니다. 권수가 아니라 습관에 집중하다 보면, 아이도 어느새 책 읽기에 재미를 붙인 걸 확인할 수 있을 거예요. 그렇다면 진정한 독서란 무엇이고, 또 어떻게 해야 그걸 습관으로 키울 수 있을까요?  아이가 독서의 주체가 되기 위해서는 단순히 많은 책을 읽는 것보다 한 권이라도 '깊이 있게' 읽는 것이 중요합니다. 크리에이터 아톰이 준비한 키트, 패널시어터를 통해 '직접' 이야기 속의 주인공이 되어 그림책 속으로 다이빙해보아요!    패널시어터란 검은색 패널(Panel, 판)으로 이루어진 작은 시어터(Theater, 극장)이에요. 부직포의 일종인 P페이퍼로 만들어져, 보풀과 정전기를 이용해 고정 장치 없이도 종이 인형을 붙였다 뗐다 할 수 있답니다. 패널시어터만 있으면 아이가 그림책 이야기 속의 상황을 인형극으로 연출할 수 있어요.      전래동화 <해와 달이 된 오누이>와 <며느리 방귀>를 인형극으로 표현해보아요. 스토리라인을 완벽히 이해해 그걸 표지와 무대 디자인으로 표현하고, 등장인물의 상황과 감정에 이입해 연기할 수 있답니다. 수업이 끝나더라도, 집에 있는 수많은 그림책으로 새로운 인형극 놀이를 즐길 수 있어요.  마지막으로 세상에 하나밖에 없는 나만의 이야기를 만들어 인형극으로 구현해 봅니다. 아톰이 직접 제작한 감정 주사위와 스토리 주사위만 있으면, 어린 아이들도 쉽게 이야기의 구성요소를 학습할 수 있지요. 자 모두들, 이야기꾼이 될 준비가 되셨나요? #시나리오 작가 #20년 경력 강사 #누적 수강생_9000여 명     드라마 <부자의 탄생 (2010)>, <화려한 유혹 (2015)> 과 여러 단편 영화에서 연출 및 시나리오 대본 작업을 진행했습니다. 2021년에는 경기콘텐츠진흥원의 시나리오 기획개발 지원사업 시나리오 부문에서 "우수상"을 수상하는 등 스토리텔링 작가로서 활발하게 활동하고 있습니다. 그 과정 속에서 이야기를 시각화하는 즐거움을 경험했고, 아이를 키우면서 "그림책"이 제 모든 경험의 집합체라는 생각이 들었습니다.  그림책으로 하나의 극을 연출한다는 건 그 책의 전문가가 되는 것과 마찬가지입니다. 영화의 경우, 총괄자인 감독이 그 누구보다 작품에 대한 이해도가 높아야 하는 것처럼 말이죠. 따라서 아톰의 인형 극장 클래스는 그림책 줄거리뿐만 아니라, 등장인물의 특징과 심리 상태부터 인물 간의 관계, 각 상황의 디테일한 설정까지 아이가 해석하고 상상할 수 있도록 도와줍니다. 교육, 출판, 방송, 영화 등 다양한 콘텐츠를 기획하고 개발하며 얻은 노하우를 꾹꾹 눌러 담았답니다.  학교에서 패널시어터를 활용한 동화 수업을 진행할 때면, 직접 해보고 싶다는 아이들이 너무 많았어요. 쉬는 시간마다 "만져 봐도 돼요?" "이거 어디서 사요?" "와, 이거 종인데 붙어요?" 라며 좋아하던 아이들에게 약속했습니다. 꼭 모든 아이들에게 패널시어터로 책놀이를 경험할 수 있는 기회를 선물하겠다고요. 이제 그 약속을 지키려 합니다.  그렇다고 해서 그냥 노는 활동이 아니에요. 프로그램을 진행하다 보면 자연스럽게 국어 교과 과정에 노출시킬 수 있습니다.   [관련 국어 학습 단원] 아톰 책놀이 프로그램은 놀이형 독서교육으로서의 독창성과 전문성을 인정받아, 2021년 하반기 유네스코 문학창의도시 "경기도 부천"의 시립도서관, 초등학교 방과후 책놀이 수업 프로그램으로 활용되고 있습니다.     22\n:\n30\n:\n06\n남음  클래스101 | 세상의 모든 클래스, 클래스101                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
# 237   카드 부채 손거울 목걸이 수저 받침대 액자 탁상등 필름지 사용법 볼록한 면의 필름지 처리 꽃의 건조 방법            안녕하세요, 프레스플라워 공예를 하는 프레스코21입니다. '프레스플라워(압화) 공예'란, 흔히 볼 수 있는 산과 들의 야생화, 이름 모를 잡초들과 과일 야채 등을 여러 가지 형태로 처리하고 손질하여 평면으로 급속 건조한 후 일반 생활용품, 액세서리, 액자, 가구 등에 다양한 기법으로 표현하는 완성도 높은 꽃 예술을 말합니다.   학교 졸업 후 처음 직장을 은행에서 시작하게 되었습니다. 옛날 은행 객장에는 항상 생화로 된 꽃꽂이가 고객들을 반기고 있었습니다. 일주일에 한 번씩 바뀌는 꽃을 보며 아름다움과 새로움에 기뻤습니다. 일이 끝난 후 꽃꽂이 수강을 받고 자격증을 취득하였습니다. 시간이 흘러 낮에는 은행원으로 밤에는 꽃꽂이 강사로 활동했습니다. 바쁜 일정에 힘은 들었지만 늘 싱싱하고 예쁜 꽃을 보는 순간은 행복했습니다. 그 아름답던 꽃이 시들어가는 모습을 보며 조금만 더 오래 볼 수 있었으면 하는 바람과 고민이 시작되었습니다. 압화의 불모지였던 우리나라 현실에 모든 걸 처음으로 시작해야 했습니다. 연구를 위해 외국을 수십 차례 다녀오고 압화와 어울리는 재료들을 하나둘씩 만들어나갔습니다. 압화를 알리기 위해 새벽 비행기를 타고 서울에서 부산 대전 대구 등 전국 여성회관, 평생교육원, 농업기술센터, 직무연수 과정 등에서 강의를 진행하였습니다. 늘어나는 수강생들에게 기술을 좀 더 효율적으로 전달하기 위해 우리나라 최초로 압화 전문 사이트를 개설하였습니다. 알려지지 않은 압화를 위해 사이트 제작도 생소했던 시절 저를 향해 모두들 무모하다고 만류했습니다. 작업 과정 디자인들을 제공하며 강사들이 강의하기에 부족함이 없도록 세미나와 전시를 통해 압화를 알려 왔습니다. 강사들의 원활한 재료 공급을 위해 프레스코21을 창립하고 쇼핑몰을 오픈하여 지금까지 30여 년 압화의 개발과 연구에 매진하고 있습니다.   나와 함께 오랫동안 아름답고 행복한 취미를 찾으신다면 프레스플라워(압화) 공예를 추천하고 싶습니다.   에폭시 레진으로 작업된 트레이와 와인 렉..   에폭시 레진으로 완성된 도자기 제품들..   십 년이 지나도 변하지 않는 액자 작품..   uv 레진으로 완성된 자개 목걸이..   문구류들..   uv 레진으로 완성된 액세서리들..   아크릴 수지를 이용한 테이블..   한지를 이용해 마감한 스탠드..  이렇게 압화는 작은 열쇠고리 같은 액세서리부터 큰 가구까지 모든 인테리어와 생활용품에 응용되어 우리 가까이에 있습니다.   귀중한 자료로서 식물 표본 전시로도 활용되고 있지요. (장소/ 서울대공원 전시실)   (장소/대전 국립 과학관)   최근 많은 동영상이나 강좌들이 생겨나면서 아주 짧은 시간에 습득 후 자격증을 취득하는 사례가 늘고 있습니다. 압화는 가장 기본이 되는 꽃의 채집 건조 과정부터 작업 중에 생긴 제습 작업을 충분히 해 줘야만 색의 변색을 막을 수 있고 오랫동안 유지 할 수 있습니다. 하루 2~3시간 얕은 기술로는 압화의 참 매력을 느낄 수 없습니다. 본 강의에서는 기본을 탄탄히 하고 다양한 마감법의 특징들을 정확하게 짚어 보기로 하려 합니다.    22\n:\n29\n:\n53\n남음  클래스101 | 세상의 모든 클래스, 클래스101                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 238              기본도형을 활용한 모델링 볼륨빌더를 활용한 모델링 스플라인을 활용한 모델링 부울을 활용한 모델링 자유롭게 구르는 공 - 리지드 바디 부풀어오르는 풍선 - 소프트 바디 서로 엮여있는 쇠사슬              다양한 재질감을 표현하는 방법 기본적인 애니메이션 익히기 사실적인 렌더링 노하우   안녕하세요 3D 모션그래픽 디자이너로 활동중인 레블디자인입니다. 현재는 프리랜서 디자이너 생활을 하며 유튜브 '레블디자인' 채널에서 다양한 디자인 관련 콘텐츠를 만들고 있습니다. 이번 클래스를 통해 오랜기간에 걸쳐 습득한 Cinema4d, Octane 노하우를 이번 기회에 공유하려고 합니다.  물론 저 또한 3D 모션그래픽 디자이너가 되기까지의 과정은 순탄하진 않았습니다. 하지만 저는 여러분에게 3D라는 새로운 디자인 언어를 최대한 쉽고 빠른 지름길로 알려드리려 합니다. 과정이 너무 어렵고 힘들면 결과가 아무리 좋다고 한들 지치기 쉽다는걸 누구보다 잘 알기 때문입니다.   3D 모션그래픽을 이제까지 너무 어렵고, 배우기 어려운 영역으로만 생각하셨나요? 저도 역시 그렇게 생각했지만 막상 배우고 나니 정말 재밌는 공부였습니다. 내가 상상한 것들을 내 손으로 직접 구현하는 재미에 매료되어 3D모션그래픽을 하면 할수록 점점 더 빠져들게 된 것 같아요. 저는 과감히 여러분도 저와 함께 배워나간다면 쉽게 익히실 것이라고 말씀드릴 수 있습니다.  저도 처음에는 2D 모션그래픽 디자이너로 활동을 시작했습니다. 하지만 2차원의 표현에 있어 한계를 마주하였습니다. 이미 2D모션 그래픽 시장엔 어마어마한 실력자들이 가득했고, 그들이 만들어 놓은 문법을 저도 모르게 반복하고 있었습니다. 때문에 쉽게 매너리즘에 빠지게 되었고 제 포트폴리오를 발전시키는 데에 큰 어려움을 느끼게 되었습니다. 점점 디자인의 즐거움을 잃어가며 디자이너로써 경쟁력도 잃어가고 있었죠.  그러던 중 유튜브의 해외 디자이너들의 3D 모션그래픽강의를 만나게 되었고 독학으로 다양한 3D프로그램을 익히기 시작하였습니다. 지금까지 표현하지 못했던 영감들을 3D영상으로 만들다보니 제 포트폴리오는 눈에 띌 정도로 경쟁력이 생기게 되었습니다. 다양한 프로젝트들을 진행해오면서 어느새 모션그래픽 디자이너로 인정받게 되었습니다. 3D를 공부하는 과정에서 Cinema 4D와 Octane의 조합은 제한된 시간안에 3D의 기본 개념을 통달할 수 있는 유일한 지름길이라고 말씀드리고 싶습니다. 그런 이 두가지 프로그램의 기본적인 기능들부터 잠재성을 최대치로 활용하는 노하우를 알려드릴게요. 3D의 기본부터 응용법까지 쉽게 익히실 수 있을거에요.  가장 기초적인 모델링부터 시작하여 텍스쳐, 애니메이션 더 나아가 라이팅 렌더링까지! 그동안 다양한 채널들에서 보고 놀라워만 보이던 3D모션그래픽을 직접 여러분의 손으로도 만들어 볼거에요.     After Effects를 통한 색 보정 노하우까지 배우신다면 실사인지 그래픽인지 구분이 안가는 극강의 리얼리즘을 구현하실 수 있게 될겁니다. 다양한 재질감을 덧대고 현실속에서 느껴왔던 빛과 공기를 더하면 마치 사진과 같은 순간들을 마주하실 수 있을거에요.   아무리 입문자라도 이번 클래스를 함께 들으시며 따라오다 보면 "3D 모션그래픽, 생각보다 쉬운거였구나!" 라고 느끼게 될것입니다. 여러분의 작업물이 더욱 재미있어지고, 동시에 퀄리티도 올라갈 수 있도록 레블디자인이 함께해드리겠습니다. 5일\n08\n:\n29\n:\n39\n남음  클래스101 | 세상의 모든 클래스, 클래스101                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# 239   첫째, 프로그램 동산 주식프로그램 강의는 모의투자가아니라 실제 금액으로 진행합니다. 그러므로 강의의 안내에 따라서 실전 계좌를 생성하면 됩니다. 강의에서는 10만원의 금액으로 진행합니다. 무리한 금액으로 학습을 따라오다가 손실이 났을 경우 모든 책임은 본인에게 있으니깐 꼭 주의해주세요!  둘째, 프로그램 동산 코딩 플랫폼의 특징은 '항상 흥미롭고 재밌게 코딩하자' 라는 의미가 많이 내포돼 있습니다. 그러므로 컴퓨터에 앉아서 혼자 코딩하면 지치고 많이 외롭습니다. 그래서 프로그램 동산 커뮤니티(네이버 카페)에서 많은 분들과 소통하면서 계속해서 재밌고 활기차게 발전해 나가길 바라겠습니다!  셋째, 프로그램 동산은 프로그램과 관련한 다양한 강의들이 있고 특정 강의를 제외하고는 모두 무료이며 계속 많아지고 있습니다. 그러다 보니 수강하는 순서를 문의하시는 분들이 많습니다. 클래스 101을 시작점으로 추천드리겠습니다. 난이도가 올라가는 방식입니다. 클래스101수강(예제코드는 코칭권 설명란 참조) -> 유튜브 백테스팅 구축 수강(영상과 코드 무료) -> 유튜브 성과검증 구축 수강 (영상과 코드 무료) 또는 코인 거래 구축 수강(영상과 코드 무료) 형태로 진행하면 좋습니다. 뒷부분부터 수강하면 난이도가 어려워서 따라오기 힘듭니다. 그러므로 클래스101부터 꼭 완강해야 합니다! 증권 코딩을 넘어 다양한 분야에서도 쓰일 수 있게 재밌게 배워봐요. 우리는 할 수 있습니다. 화이팅!  *주식 외에 선물, 코인 등 다양한 학습을 원한다면 강의목록을 확인! https://cafe.naver.com/programgarden/857  넷째, 프로그램 동산 커뮤니티에서는 학습에서 배운 내용을 확장해서 코드를 공유해 주시는 분들이 많습니다. 프로그램 동산 학습자들 모두가 더욱더 발전하길 바라는 좋은 마음으로 공유해 주시는 고마운 분들입니다. 그러므로 CLASS101을 완강하고 추가 학습을 할 때 공유된 파일로 학습하게 될 확률이 높습니다. 공유해 주신 분들에게 힘이 될 수 있도록 고마움을 표현해 주세요.  다섯째, "시스템 트레이딩으로 돈을 잘 벌 수 있는가?"라는 문의가 많습니다. 그럴때는 이렇게 생각해 보면 좋습니다. "손으로 할 때는 수익을 잘 냈는가?" 그 말은 코딩과 투자는 같이 공부해야 하는 영역입니다. 그러므로 프로그램 동산은 공개적인 공간에 절대 수익 인증을 하지 않습니다. 왜냐하면 코딩을 배우려는 분들에게 허황된 목표를 심어주지 않기 위함입니다. 그래서 저와 수강생분들은 시스템 트레이딩 수익 인증을 카페에서 하고 서로에게 피드백을 주고있습니다. 그중에서도 오랫동안 노력하신 고수분들이 계시고 코딩에 대해선 일관된 견해들을 가지고 있습니다. 외에도 많은 장점들이 있습니다. 장점들을 모두 활용하기 위해선 많은 공부량과 꾸준함이 필요합니다. 그러므로 클래스101 수강할 때 마음의 준비를 단단히 잡고 임해주시면 좋습니다!  여섯째, 프로그램 동산으로부터 코딩을 시작하신 분들에게 항상 감사한 마음을 가지고 각종 유료/무료 영상들을 제작하고 있습니다. 수강생분들이 코딩의 매력에 빠질 수 있게 정체되지 않고 계속해서 발전하는 강의들을 만들어 가겠습니다. 그러므로 강의에서 부족한 부분이 느껴진다면 언제든지 피드백을 해주세요! 꾸준하게 개선해서 더 멋진 강의를 만들어 가겠습니다. 감사합니다.  유의사항을 읽어주셔서 감사해요. 이어서 재밌고 흥미로운 프로그램 동산 소개글을 읽어볼까요? :)  시스템 트레이딩 실제 화면 이미 주식으로 큰 수익을 내고 있는 분들과 주식을 시작하려고 하는 사람들이 중요하게 생각하는 것은 아마 '어떤 종목에 투자할 것인가'입니다. 금줄 하나를 찾기 위해서 적게는 수십 가지, 많게는 수백 가지의 주식 종목을 분석해야 합니다. 하지만 사람이다 보니 몇 가지의 주식 종목을 분석하는데도 많은 시간이 소요됩니다. 또 마땅히 본인만의 투자 원칙이 없는 분들은 '감'에 치중해 수익도 잘 못내는 분들도 있습니다.  우리 클래스에서 배울 시스템 트레이딩은 좋은 종목을 구별하는 투자 방식을 코딩 시스템인 파이썬으로 구축해 수 백가지, 수 천 가지의 주식 종목을 한 번에 분석하는 것입니다. 주식 종목을 선택해야 되는 시간과 에너지를 아낄 수 있고, 더 이상 감에 치중하지 않고 정교한 타이밍에 매매도 할 수 있습니다.  주가는 시장의 흐름을 읽는 것이 중요합니다. 만약 시장에 발 빠른 대응을 하지 못한다면 아무리 좋은 주식 트레이딩 시스템이라도 유명무실하겠죠? 이 클래스에서는 뉴스 내용을 활용해서 연관된 주식들을 매수 또는 매도할지 결정할 수 있습니다 보통 키워드를 뽑아 쓰는 크롤링 방식이 유명하지만 HTML 언어 활용을 알아야해서 처음 접하면 복잡 할 수 있습니다. 그래서 우리는 '프로그램 동산'이 사용하는 더 쉬운 방식으로 기사를 가져올 거예요. 그러므로 자연스럽게 위기에 대응할 수 있는 '안전핀'을 얻게 되고, 신문기사 분석으로 누구보다 발 빠르게 주가에 대응할 수 있습니다. 한 번 사는 인생, 정해진 시간 안에 더 많은 행복을 누려야 합니다. 주식 자동화 시스템을 만든 후 주식을 보는 시간을 없애고 빠르게 급변하는 주식시장에 대응할 수 있는 저만의 '비서'를 만들었습니다. 그러다 보니, 이번 주 내내 주식 앱을 켜보지 않았네요!   프로그램동산이라는 이름으로 강의를 수 년째 해왔습니다. 주식도, 코딩도 접해본 적 없는 초보 분들을 많이 지도했고 그분들에게 전 단호하게 말했습니다. "코딩 배우면서 투자방법도 공부하세요"라고 말이죠. 백지상태에서 코딩을 배우면서 시스템에 최적화되도록 투자방법도 연구해야만 완벽해집니다. 그러므로 코딩에 대해선 걱정 마세요. '프로그램 동산'이 많은 수강생들이 필요로 하는 로직들을 강의 내용에 최대한 담았습니다!   다양한 증권사들이 시스템 트레이딩에 필요한 프로그램을 가지고 있습니다. 이 클래스에서는 이베스트의 Xing API 를 사용합니다. Xing API는 초보자들이 접근하기 쉬운 로직을 가집니다. 그리고 강의는 주식 시스템 구축에 초점을 맞춰서 빠른 기간 안에 이해하고 완성해서 스스로도 API 구축이 쉽게 느껴지도록 만든다는 장점을 지닙니다. 그래서 Xing API가 훨씬 쉽게 배운다는 평을 수강생들로부터 많이 들었습니다. 우리는 전문가가 아니잖아요? 그러므로 빨리 배우고 구축하는 게 중요하죠! 증권 프로그램의 접근성부터 다루기 쉬운 다양한 데이터 처리 등 여러 가지 부분들이 입문자가 배우기 좋아서 선택했습니다. 저 또한 이베스트의 프로그램으로 투자를 하고 있습니다. 금융 코딩 강의를 하면서 수 백 명으로부터 피드백을 받았습니다. 저도 초보였던 시절을 떠올리며 입문자들은 어떤 부분을 가장 어려워하는지 조언을 새겨듣고 연구했습니다. 그러다가 가장 중요한 한 가지를 깨우쳤는데요! 코드 배우는 게 중요하지만 코드보다 더 중요한 게 알고리즘 흐름도입니다. 예로 들면 코드는 반복적으로 따라서 타이핑하면 자연스럽게 학습됩니다. 하지만 지루하고 재미도 없습니다. 또한 코드를 익혔다고 해서 실전에 사용하는 알고리즘을 구현할 수 있는 건 아닙니다. 그래서 알고리즘 흐름도로 프로그램이 어떻게 돌아가는지 확인하고 코드로 접근하면, 코드를 이해하는 게 훨씬 재밌고 쉽고 접근성이 좋아집니다.  주식은 수많은 사람들이 한 푼이라도 더 벌기 위해 경쟁하는 게임 속 던전과 똑같다는 느낌을 받고 있습니다. 시스템 트레이딩으로 돈을 잘 벌면 더 할 나위 없이 재밌겠지만, 우선은 코딩을 배우는 과정에서 제가 느끼는 부분들을 수강생분들도 최대한 느끼길 바라는 마음으로 주식 자동화 코딩을 가르치고 있습니다. 코딩을 배우는 과정은 매 순간이 흥미롭고 모든 과정마다 결과물을 보아야 더 재밌습니다. 시간 가는 줄 모르고 주식 자동화 시스템을 모두 학습한 자신을 발견할 겁니다!   스스로 구축하는 단계에 이른다면 저 처럼 주식창을 보면서 코딩으로 옮기게 될 거예요! 강의 중 연습용으로 실제 거래까지 해봅니다. 직접 만든 알고리즘으로 구현된 시스템을 보게 될 거예요. 우리는 클래스를 통해서 코딩의 재미를 느끼고 완성된 작품을 만들기까지 수 많은 과정을 매 순간 설레고 재밌게 배웁니다. 그리고 어떻게 코드를 확장하면 되는지, 코드 보는 방법을 집중 ...
#
#     keyword
# 0    개발
# 1    개발
# 2    개발
# 3    개발
# 4    개발
# ..   ..
# 235  개발
# 236  개발
# 237  개발
# 238  개발
# 239  개발
#
# [240 rows x 3 columns]

# %%
df.to_csv('class101_12.csv')
